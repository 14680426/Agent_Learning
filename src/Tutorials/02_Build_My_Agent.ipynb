# %% [markdown]
# # 创建 Agent 项目和本地测试环境
#
# LangChain 提供了一套强大的开发与调试工具链，帮助开发者高效构建、测试和优化基于大模型的智能代理（Agent）系统。其中，**LangSmith + Studio** 是 LangChain 官方推荐的集成开发与测试环境，特别适合在本地进行 Agent 的可视化交互、调试和性能评估。
#
# # ✅ **LangSmith 与 Studio 的核心作用**
#
# - **LangSmith** 是 LangChain 生态中的核心平台，用于跟踪、监控、评估和优化 LLM 应用程序。它支持完整的日志记录、调用追踪、提示工程管理以及模型性能分析。
# - **Studio** 是 LangSmith 提供的一个专门的 **Agent IDE（集成开发环境）**，允许开发者在本地环境中对实现智能体服务器 API 协议的代理系统进行：
#   - **可视化调试**：实时查看 Agent 的执行流程、工具调用顺序、中间状态等；
#   - **交互式测试**：通过图形界面输入问题，观察 Agent 的响应行为；
#   - **可复现性调试**：保存并回放整个对话历史，便于定位问题。
#
# # 🛠️ **Studio 的主要功能亮点**
#
# 1. **可视化 Agent 执行流程**
#    - 可以清晰看到 Agent 如何解析用户意图、选择工具、调用 API、生成最终回答。
#    - 支持树状图展示多轮推理路径，便于理解复杂逻辑。
#
# 2. **交互式调试**
#    - 在浏览器中直接输入指令，即时获取 Agent 响应，无需频繁运行代码。
#    - 支持断点设置、变量查看、工具调用拦截等功能，提升调试效率。
#
# 3. **集成跟踪（Tracing）**
#    - 自动记录每次调用的完整上下文，包括 Prompt、LLM 输出、工具调用结果等。
#    - 支持导出为 JSON 或 CSV，方便后续分析。
#
# 4. **评估（Evaluation）**
#    - 内置多种评估指标（如准确性、一致性、安全性），可自动打分。
#    - 支持人工标注和 A/B 测试，持续优化 Agent 表现。
#
# 5. **提示工程（Prompt Engineering）**
#    - 提供提示词版本控制、A/B 测试、性能对比等功能。
#    - 可快速迭代优化 Prompt 模板，提升输出质量。
#
# # 🌐 **使用场景示例**
#
# 假设你正在开发一个“电影信息查询 Agent”，它可以：
# - 理解用户提问；
# - 调用外部 API 查询电影详情；
# - 返回结构化答案。
#
# 你可以通过 Studio：
# - 输入：“《盗梦空间》的导演是谁？”
# - 观察 Agent 是否正确识别了意图；
# - 查看是否调用了正确的工具（如 `search_movie`）；
# - 分析返回结果是否符合预期；
# - 修改 Prompt 后立即验证效果。
#
# # 🔧 **如何开始使用？**
#
# 1. 注册并登录 [LangSmith](https://smith.langchain.com)；
# 2. 创建一个新的 Agent 项目；
# 3. 使用 `langchain-studio` 工具启动本地服务；
# 4. 在浏览器中打开 Studio 页面，连接到你的 Agent；
# 5. 开始交互式测试和调试。
#
# > 💡 提示：Studio 支持与主流 LLM 框架（如 LangChain、LlamaIndex）无缝集成，只需配置正确的 API 密钥和端点即可。
#
# ---
#
# ### ✅ 总结
#
# LangChain 的 **Studio + LangSmith** 集成环境极大地简化了 Agent 的开发流程。它不仅是一个测试工具，更是**Agent 全生命周期管理平台**，从设计、开发、调试到部署、监控、优化，提供一站式解决方案。对于希望快速构建可靠、可维护智能代理的开发者来说，这是不可或缺的利器。
